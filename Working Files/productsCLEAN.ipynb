# %%
import pandas as pd
from pathlib import Path

product_csv = Path("datasets", "product_info.csv")

product_df = pd.read_csv(product_csv)
product_df
# Out:
#      product_id                                       product_name  brand_id  \
# 0       P473671                            Fragrance Discovery Set      6342
# 1       P473668                            La Habana Eau de Parfum      6342
# 2       P473662                          Rainbow Bar Eau de Parfum      6342
# 3       P473660                               Kasbah Eau de Parfum      6342
# 4       P473658                          Purple Haze Eau de Parfum      6342
# ...         ...                                                ...       ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
# ...

# %%
product_list = product_df[['product_name', 'brand_name', 'rating', 'reviews']]
product_list
# Out:
#                                            product_name          brand_name  \
# 0                               Fragrance Discovery Set               19-69
# 1                               La Habana Eau de Parfum               19-69
# 2                             Rainbow Bar Eau de Parfum               19-69
# 3                                  Kasbah Eau de Parfum               19-69
# 4                             Purple Haze Eau de Parfum               19-69
# ...                                                 ...                 ...
# 8489                   Couture Clutch Eyeshadow Palette  Yves Saint Laurent
# 8490                              L'Homme Eau de Parfum  Yves Saint Laurent
# 8491                   Mon Paris Eau de Parfum Gift Set  Yves Saint Laurent
# 8492                           Y Eau de Parfum Gift Set  Yves Saint Laurent
# 8493  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...  Yves Saint Laurent
#
#       rating  reviews
# 0     3.6364     11.0
# ...

# %%
productclean_list = product_list.dropna(axis = 0)
productclean_list
# Out:
#                           product_name          brand_name  rating  reviews
# 0              Fragrance Discovery Set               19-69  3.6364     11.0
# 1              La Habana Eau de Parfum               19-69  4.1538     13.0
# 2            Rainbow Bar Eau de Parfum               19-69  4.2500     16.0
# 3                 Kasbah Eau de Parfum               19-69  4.4762     21.0
# 4            Purple Haze Eau de Parfum               19-69  3.2308     13.0
# ...                                ...                 ...     ...      ...
# 8487              Black Opium Gift Set  Yves Saint Laurent  3.5000      2.0
# 8488      Libre Eau de Parfum Gift Set  Yves Saint Laurent  5.0000      1.0
# 8489  Couture Clutch Eyeshadow Palette  Yves Saint Laurent  4.4286      7.0
# 8490             L'Homme Eau de Parfum  Yves Saint Laurent  4.6367    556.0
# 8491  Mon Paris Eau de Parfum Gift Set  Yves Saint Laurent  5.0000      2.0
#
# [8216 rows x 4 columns]
