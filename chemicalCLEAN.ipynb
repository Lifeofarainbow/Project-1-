# %%
import pandas as pd
from pathlib import Path

chemical_csv = Path("datasets", "p65chemicalslistexcel.csv")

chemical_df = pd.read_csv(chemical_csv)
chemical_df
# Out:
#                                                Chemical  \
# 0            A-alpha-C (2-Amino-9H-pyrido[2,3-b]indole)
# 1                                   Abiraterone acetate
# 2                                          Acetaldehyde
# 3                                             Acetamide
# 4                                      Acetazolamide
# ...                                                 ...
# 1017                                                NaN
# 1018                                        Zalcitabine
# 1019                                   Zidovudine (AZT)
# 1020                                          Zileuton
# 1021  Zineb  Delisted October 29, 1999 [Click here f...
#
#                    Type of Toxicity Listing Mechanism      CAS No.  \
# 0                            cancer                AB   26148-68-5
# 1      developmental, female, male                 FR  154229-18-2
# 2                            cancer               SQE      75-07-0
# 3                           cancer                 AB      60-35-5
# 4                   developmental                  FR      59-66-5
# ...                             ...               ...          ...
# 1017                            NaN               NaN          NaN
# 1018                        cancer                 LC    7481-89-2
# 1019                        cancer                 LC   30516-87-1
# 1020  cancer, developmental, female                FR  111406-87-2
# 1021                         cancer                AB   12122-67-7
#
#      Date Listed NSRL or MADL (µg/day)a
# 0       1-Jan-90                      2
# 1       8-Apr-16                    NaN
# 2       1-Apr-88        90 (inhalation)
# 3       1-Jan-90                     10
# 4      20-Aug-99                    NaN
# ...          ...                    ...
# 1017         NaN                    NaN
# 1018    7-Aug-09                    NaN
# 1019   18-Dec-09                    NaN
# 1020   22-Dec-00                    NaN
# 1021    1-Jan-90                    NaN
#
# [1022 rows x 6 columns]

# %%
chemical_list = chemical_df[['Chemical', 'Type of Toxicity']]
chemical_list
# Out:
#                                                Chemical  \
# 0            A-alpha-C (2-Amino-9H-pyrido[2,3-b]indole)
# 1                                   Abiraterone acetate
# 2                                          Acetaldehyde
# 3                                             Acetamide
# 4                                      Acetazolamide
# ...                                                 ...
# 1017                                                NaN
# 1018                                        Zalcitabine
# 1019                                   Zidovudine (AZT)
# 1020                                          Zileuton
# 1021  Zineb  Delisted October 29, 1999 [Click here f...
#
#                    Type of Toxicity
# 0                            cancer
# 1      developmental, female, male
# 2                            cancer
# 3                           cancer
# 4                   developmental
# ...                             ...
# 1017                            NaN
# 1018                        cancer
# 1019                        cancer
# 1020  cancer, developmental, female
# 1021                         cancer
#
# [1022 rows x 2 columns]

# %%
chemicalclean_list = chemical_list.dropna(axis = 0)
chemicalclean_list
# Out:
#                                                Chemical  \
# 0            A-alpha-C (2-Amino-9H-pyrido[2,3-b]indole)
# 1                                   Abiraterone acetate
# 2                                          Acetaldehyde
# 3                                             Acetamide
# 4                                      Acetazolamide
# ...                                                 ...
# 1016                 2,6-Xylidine (2,6-Dimethylaniline)
# 1018                                        Zalcitabine
# 1019                                   Zidovudine (AZT)
# 1020                                          Zileuton
# 1021  Zineb  Delisted October 29, 1999 [Click here f...
#
#                    Type of Toxicity
# 0                            cancer
# 1      developmental, female, male
# 2                            cancer
# 3                           cancer
# 4                   developmental
# ...                             ...
# 1016                         cancer
# 1018                        cancer
# 1019                        cancer
# 1020  cancer, developmental, female
# 1021                         cancer
#
# [975 rows x 2 columns]
